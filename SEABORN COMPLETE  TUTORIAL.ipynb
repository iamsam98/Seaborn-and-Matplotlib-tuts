# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style= 'darkgrid')

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ###  SCATTER PLOT

# %%
sns.relplot(x='total_bill', y='tip',data = tips)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='sex',style='time')

# %%
sns.relplot(x='total_bill',y='tip',hue='size',data=tips, palette= 'Paired',)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size',sizes= (15,200))

# %% [markdown]
# ### LINE PLOT

# %%
from numpy.random import randn

# %%
df=pd.DataFrame(dict(time=np.arange(500), value= randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0 -1.157627
# 1     1 -0.767020
# 2     2  0.399342
# 3     3 -0.405441
# 4     4  0.557480

# %%
sns.relplot(x='time',y='value',kind= 'line',data=df,sort =False)

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal', kind='line', data=fmri,ci=False)

# %%
sns.relplot(x='timepoint',y='signal', kind='line', data=fmri,ci='sd')

# %%
sns.relplot(x='timepoint',y='signal',estimator=None, kind ='line', data= fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue='event',kind='line', data =fmri, ci=None)

# %%
sns.relplot(x='timepoint', y='signal', hue ='region',style='event',kind='line',data=fmri, ci=None, palette = 'Paired')

# %%
sns.relplot(x='timepoint', y='signal', hue ='region',style='event',kind='line',data=fmri, ci=None, markers= True , palette = 'Paired')

# %%
sns.relplot(x='timepoint', y='signal', hue ='event',style='event',kind='line',data=fmri, ci=None)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dots=sns.load_dataset('dots').query("align=='dots'")

# %%
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
sns.relplot(x='time',y='firing_rate', hue ='coherence',  kind='line', data=dots, style='choice',palette = 'Paired')

# %%
sns.relplot(x='time',y='firing_rate',hue ='coherence',size='coherence', style='choice', kind='line',data= dots, palette='Paired')

# %%
df=pd.DataFrame(dict(time=pd.date_range('2019-06-02',periods =500),value =randn(500).cumsum()))

# %%
df
# Out:
#           time      value
# 0   2019-06-02  -0.377208
# 1   2019-06-03  -0.538663
# 2   2019-06-04  -0.658371
# 3   2019-06-05  -0.164753
# 4   2019-06-06  -1.297999
# ..         ...        ...
# 495 2020-10-09  -9.847107
# 496 2020-10-10 -10.210475
# 497 2020-10-11 -10.446824
# 498 2020-10-12 -11.393692
# 499 2020-10-13  -9.184983
#
# [500 rows x 2 columns]

# %%
g=sns.relplot(x='time',y='value',kind='line',data=df)
g.fig.autofmt_xdate()

# %%
sns.relplot(x='total_bill',y='tip',hue= 'smoker',col='size', data=tips)

# %%
sns.relplot(x='timepoint', y='signal',hue='subject',col='region',row='event',height=9,kind ='line', data= fmri,palette='Paired')

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='size',data=tips, col_wrap=3,height=3)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='size',col_wrap =2,data=tips)

# %%
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
 sns.lineplot(x='timepoint',y='signal',style='event',hue='region',data=fmri,ci=70, err_style='bars', markers=True)

# %%
sns.lineplot(x='timepoint',y='signal',hue='event',units='subject',estimator=None,lw=1,data=fmri.query("region=='frontal'"))

# %%
fmri.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.lineplot(x='time',y='firing_rate',hue='coherence',style='choice',data=dots)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='smoker',size='size', palette ='Paired')

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### CATEGORICAL DATA PLOTING
# #### 1. catplot()
# #### 2. boxplot()
# #### 3. strippplot()
# #### 4. swarmplot()

# %%
sns.scatterplot(x='sepal_length',y='petal_length', hue='species',data=iris)

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='day',y='total_bill',hue='smoker', data= tips, palette='Paired', jitter=False)

# %%
sns.catplot(x='day',y='total_bill',hue='smoker', data= tips,kind='swarm')

# %%
sns.catplot(x='smoker',y='tip',data=tips, order=['No','Yes'], jitter= False)

# %%
tips.head()

# %%
sns.catplot(x='day',y='total_bill', kind='box',hue='smoker',data=tips, palette ='Paired')

# %%
sns.catplot(x='day',y='total_bill', kind='box',hue='sex',data=tips, palette ='Paired',dodge=False)

# %%
diamonds=sns.load_dataset('diamonds')

# %%
sns.catplot(x='color',y='price',kind='boxen',data=diamonds.sort_values('color'))

# %%
sns.catplot(x='total_bill',y='day',hue='time',kind='violin',data=tips)

# %%
sns.catplot(x='day',y='total_bill',kind='violin', height=8,data=tips)
sns.catplot(x='day',y='total_bill',kind='swarm',height=8,data=tips)

# %%
sns.catplot(x='sex',y='survived',hue='class',kind='bar',data=titanic,palette='Paired')

# %%
sns.catplot(x='deck',kind='count',palette ='Paired', data=titanic)

# %%
sns.catplot(x='sex',y='survived',kind='point',data=titanic,hue='class')

# %% [markdown]
# ##  VISUALIZING THE DISTRIBUTION OF THE DATA
# ### 1.distplot()
# ###  2. kdeplot()
# ### 3.jointplot()
# ###  4. rugplot()

# %%
x=randn(100)

# %%
sns.distplot(x, bins=25)

# %%
sns.kdeplot(x,shade=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x=tips['total_bill']
y=tips['tip']

# %%
sns.jointplot(x='total_bill',y='tip', kind='kde',data=tips)

# %%
sns.pairplot(iris)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
